# %% [markdown]
# # Python Data Cleaning

# %% [markdown]
# ### Import Necesities

# %%
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load Data

# %%
raw_data = pd.read_csv('pythons.csv')

# %% [markdown]
# ### Questions Data Will Answer

# %% [markdown]
# - Are sightings of Burmese pythons in the wild increasing? (Client wants an analysis with visualizations)
#
# - Which three counties are most affected? (Analysis + visualization)
#
# - Are there geographic hotspots? If so, can you estimate the likelihood that volunteers would find pythons if we sent patrols to those areas between today's date and Dec 31st? (Analysis + viz)
#
# - When are people most likely to spot pythons, and why? (Analysis + viz)
#
# - Are sightings cyclical? (Analysis + viz)
#
# - How many python observations do you predict will be recorded for the full 2019 year? (time-series analysis)
#
# - For purposes of developing a social media/citizen science campaign, the client would like to know:
#
#  - Should we be using iNaturalist to get the public more engaged? (Back your answer with data)
#
#  - Which iNaturalist users are most active in sighting pythons?
#
#  - Which iNaturalist users are most active in identifying pythons? Hint: iNaturalist observations must be confirmed by other users...
#
#  - Which iNaturalist users are most connected in the python-spotting community (i.e. who are the influencers)?
#
#  - Is there overlap between the observers in the two datasets (i.e., are any wildlife officials also using iNaturalist)? (Hint: yes. Visualize it.)

# %% [markdown]
# ### Check Data

# %%
raw_data.head()
# Out:
#    objectid                                           Reporter  \
# 0   8303498                                Travis Mangione FWC
# 1   8303147                             Edward F. Metzger III
# 2   8298008  Michael Reupert NPS  Big Cypress National Pres...
# 3   8295649  matthew mccollister National Park Service, Big...
# 4   8295647  matthew mccollister National Park Service, Big...
#
#           ComName                         SciName OccStatus      ObsDate  \
# 0  Burmese python  Python molurus ssp. bivittatus  Positive  24 Nov 2019
# 1  Burmese python  Python molurus ssp. bivittatus  Positive  20 Nov 2019
# 2  Burmese python  Python molurus ssp. bivittatus  Positive  07 Nov 2019
# 3  Burmese python  Python molurus ssp. bivittatus  Positive  06 Nov 2019
# 4  Burmese python  Python molurus ssp. bivittatus  Positive  05 Nov 2019
#
#    DateAcc      DateEnt       DateUp                            Location  \
# 0      NaN  26 Nov 2019          NaN  Miami-Dade, Florida, United States
# 1      NaN  22 Nov 2019  22 Nov 2019     Broward, Florida, United States
# 2      NaN  12 Nov 2019          NaN     Collier, Florida, United States
# 3      NaN  07 Nov 2019          NaN     Collier, Florida, United States
# 4      NaN  07 Nov 2019          NaN     Collier, Florida, United States
#
#    Latitude  Longitude       Datum  CoordAcc           Method DataType  \
# 0  25.76191  -80.74829  WGS84            NaN              NaN      NaN
# 1  26.29298  -80.50567  WGS84            0.0  Google Maps GPS      NaN
# 2  25.86434  -81.10691  WGS84            NaN              NaN      NaN
# 3  25.83131  -80.90326  WGS84            NaN              NaN      NaN
# 4  25.87197  -81.18223  WGS84            NaN              NaN      NaN
#
#   LocalOwner                                            Habitat  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN  Edge: Roadside                                ...
# 3        NaN                                                NaN
# 4        NaN                                                NaN
#
#                                             Locality Site  InfestAcre  \
# 0  Man found and killed the python "just before t...  NaN         NaN
# 1                                                NaN  NaN         NaN
# 2                                Hy 41 south in BICY  NaN         NaN
# 3                      Big Cypress National Preserve  NaN         NaN
# 4                      Big Cypress National Preserve  NaN         NaN
#
#    GrossAcre  Abundance  Density NumCollect Percentcov  TreatArea  TreatComm  \
# 0        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN      NaN        NaN        NaN        NaN        NaN
#
#    Quantity QuantityU  TrapType  NumTraps  \
# 0       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN
#
#                                             Comments VisitType  CollectTme  \
# 0  Hunter found and killed python just outside of...       NaN         NaN
# 1                                 Yearling roadkill        NaN         5.0
# 2                  Dispatch ed by BICY Python agents       NaN         NaN
# 3            collected by T Hobbs, euthanized by NPS       NaN         NaN
# 4    female, collected by P Hobbs, euthanized by NPS       NaN         NaN
#
#   Surveyor  RecSource RecOwner   RecSrcTyp OrigName    Nativity  Host  \
# 0      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
# 1      NaN        NaN  Unknown     Android      NaN  Introduced   NaN
# 2      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
# 3      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
# 4      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
#
#    Host_Name          VerifyMthd    IDCred  Verified  \
# 0        NaN  Reporter Expertise  Credible  Verified
# 1        NaN         Photographs  Verified  Verified
# 2        NaN  Reporter Expertise  Credible  Verified
# 3        NaN  Reporter Expertise  Credible  Verified
# 4        NaN  Reporter Expertise  Credible  Verified
#
#                        Reviewer   ReviewDate  OrgSrcID  PID  Voucher  \
# 0  FWCC Exotic Species Database  05 Dec 2019       NaN  NaN      0.0
# 1  FWCC Exotic Species Database  05 Dec 2019       NaN  NaN      NaN
# 2  FWCC Exotic Species Database  14 Nov 2019       NaN  NaN      0.0
# 3  FWCC Exotic Species Database  08 Nov 2019       NaN  NaN      0.0
# 4  FWCC Exotic Species Database  08 Nov 2019       NaN  NaN      0.0
#
#                                               Museum MuseumRec Reference
# 0                                                NaN       NaN       NaN
# 1                                                NaN       NaN       NaN
# 2  HQ freezer                                    ...       NaN       NaN
# 3                                                NaN       NaN       NaN
# 4                                                NaN       NaN       NaN

# %%
#Count values of columns to see value relvance

raw_data['Reviewer'].value_counts()
# Out:
# FWCC Exotic Species Database    671
# Larry Connor, FWCC              176
# Edward Mercer                     9
# Tony Pernas                       5
# Ashley Lawrence                   4
# Larry Connor, FWCc                3
# Jake Edwards                      2
# Liz Barraco, FWCC                 2
# Pat Howell                        2
# Vanessa McDonough                 1
# Karan A. Rawlins                  1
# Name: Reviewer, dtype: int64

# %%
#Check rows where observations occured in Florida

raw_data[raw_data['Location'].str.contains('Florida')].head()
# Out:
#    objectid                                           Reporter  \
# 0   8303498                                Travis Mangione FWC
# 1   8303147                             Edward F. Metzger III
# 2   8298008  Michael Reupert NPS  Big Cypress National Pres...
# 3   8295649  matthew mccollister National Park Service, Big...
# 4   8295647  matthew mccollister National Park Service, Big...
#
#           ComName                         SciName OccStatus      ObsDate  \
# 0  Burmese python  Python molurus ssp. bivittatus  Positive  24 Nov 2019
# 1  Burmese python  Python molurus ssp. bivittatus  Positive  20 Nov 2019
# 2  Burmese python  Python molurus ssp. bivittatus  Positive  07 Nov 2019
# 3  Burmese python  Python molurus ssp. bivittatus  Positive  06 Nov 2019
# 4  Burmese python  Python molurus ssp. bivittatus  Positive  05 Nov 2019
#
#    DateAcc      DateEnt       DateUp                            Location  \
# 0      NaN  26 Nov 2019          NaN  Miami-Dade, Florida, United States
# 1      NaN  22 Nov 2019  22 Nov 2019     Broward, Florida, United States
# 2      NaN  12 Nov 2019          NaN     Collier, Florida, United States
# 3      NaN  07 Nov 2019          NaN     Collier, Florida, United States
# 4      NaN  07 Nov 2019          NaN     Collier, Florida, United States
#
#    Latitude  Longitude       Datum  CoordAcc           Method DataType  \
# 0  25.76191  -80.74829  WGS84            NaN              NaN      NaN
# 1  26.29298  -80.50567  WGS84            0.0  Google Maps GPS      NaN
# 2  25.86434  -81.10691  WGS84            NaN              NaN      NaN
# 3  25.83131  -80.90326  WGS84            NaN              NaN      NaN
# 4  25.87197  -81.18223  WGS84            NaN              NaN      NaN
#
#   LocalOwner                                            Habitat  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN  Edge: Roadside                                ...
# 3        NaN                                                NaN
# 4        NaN                                                NaN
#
#                                             Locality Site  InfestAcre  \
# 0  Man found and killed the python "just before t...  NaN         NaN
# 1                                                NaN  NaN         NaN
# 2                                Hy 41 south in BICY  NaN         NaN
# 3                      Big Cypress National Preserve  NaN         NaN
# 4                      Big Cypress National Preserve  NaN         NaN
#
#    GrossAcre  Abundance  Density NumCollect Percentcov  TreatArea  TreatComm  \
# 0        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN      NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN      NaN        NaN        NaN        NaN        NaN
#
#    Quantity QuantityU  TrapType  NumTraps  \
# 0       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN
#
#                                             Comments VisitType  CollectTme  \
# 0  Hunter found and killed python just outside of...       NaN         NaN
# 1                                 Yearling roadkill        NaN         5.0
# 2                  Dispatch ed by BICY Python agents       NaN         NaN
# 3            collected by T Hobbs, euthanized by NPS       NaN         NaN
# 4    female, collected by P Hobbs, euthanized by NPS       NaN         NaN
#
#   Surveyor  RecSource RecOwner   RecSrcTyp OrigName    Nativity  Host  \
# 0      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
# 1      NaN        NaN  Unknown     Android      NaN  Introduced   NaN
# 2      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
# 3      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
# 4      NaN        NaN  Unknown  Web Report      NaN  Introduced   NaN
#
#    Host_Name          VerifyMthd    IDCred  Verified  \
# 0        NaN  Reporter Expertise  Credible  Verified
# 1        NaN         Photographs  Verified  Verified
# 2        NaN  Reporter Expertise  Credible  Verified
# 3        NaN  Reporter Expertise  Credible  Verified
# 4        NaN  Reporter Expertise  Credible  Verified
#
#                        Reviewer   ReviewDate  OrgSrcID  PID  Voucher  \
# 0  FWCC Exotic Species Database  05 Dec 2019       NaN  NaN      0.0
# 1  FWCC Exotic Species Database  05 Dec 2019       NaN  NaN      NaN
# 2  FWCC Exotic Species Database  14 Nov 2019       NaN  NaN      0.0
# 3  FWCC Exotic Species Database  08 Nov 2019       NaN  NaN      0.0
# 4  FWCC Exotic Species Database  08 Nov 2019       NaN  NaN      0.0
#
#                                               Museum MuseumRec Reference
# 0                                                NaN       NaN       NaN
# 1                                                NaN       NaN       NaN
# 2  HQ freezer                                    ...       NaN       NaN
# 3                                                NaN       NaN       NaN
# 4                                                NaN       NaN       NaN

# %%
#Review location data

raw_data['Location'].unique()
# Out:
# array(['Miami-Dade, Florida, United States',
#        'Broward, Florida, United States',
#        'Collier, Florida, United States',
#        'Monroe, Florida, United States',
#        'Palm Beach, Florida, United States',
#        'Polk, Florida, United States', 'Orange, Florida, United States',
#        'Manatee, Florida, United States',
#        'Sarasota, Florida, United States',
#        'Volusia, Florida, United States', 'Lee, Florida, United States',
#        'Glades, Florida, United States',
#        'Okeechobee, Florida, United States',
#        'Hendry, Florida, United States',
#        'Alachua, Florida, United States',
#        'Knox, Tennessee, United States',
#        'Monroe, New York, United States',
#        'Hernando, Florida, United States',
#        'Marion, Florida, United States', 'Pasco, Florida, United States',
#        'Pinellas, Florida, United States',
#        'Highlands, Florida, United States',
#        'Osceola, Florida, United States',
#        'Charlotte, Florida, United States',
#        'St. Lucie, Florida, United States',
#        'Clay, Florida, United States', 'Martin, Florida, United States',
#        'Hillsborough, Florida, United States',
#        'Brevard, Florida, United States',
#        'Washington, Florida, United States',
#        'Flagler, Florida, United States',
#        'Charlton, Georgia, United States',
#        'Indian River, Florida, United States',
#        'Duval, Florida, United States',
#        'Seminole, Florida, United States'], dtype=object)

# %%
#Check columns with null values

raw_data.isnull().sum()
# Out:
# objectid         0
# Reporter         0
# ComName          0
# SciName          0
# OccStatus        0
# ObsDate          0
# DateAcc       4793
# DateEnt          0
# DateUp        3614
# Location         0
# Latitude         0
# Longitude        0
# Datum            0
# CoordAcc      4506
# Method        2695
# DataType      2479
# LocalOwner    4763
# Habitat       4236
# Locality      2296
# Site          4797
# InfestAcre    4681
# GrossAcre     4760
# Abundance     4798
# Density       4798
# NumCollect    1401
# Percentcov    4797
# TreatArea     4798
# TreatComm     4798
# Quantity      4687
# QuantityU     4687
# TrapType      4798
# NumTraps      4798
# Comments      2211
# VisitType     2711
# CollectTme    4570
# Surveyor      3246
# RecSource     4798
# RecOwner         0
# RecSrcTyp        0
# OrigName      2510
# Nativity         0
# Host          4798
# Host_Name     4798
# VerifyMthd      70
# IDCred           4
# Verified         0
# Reviewer      3922
# ReviewDate    3922
# OrgSrcID      4798
# PID           4798
# Voucher       4313
# Museum        2684
# MuseumRec     4225
# Reference     2480
# dtype: int64

# %%
#Check column values

raw_data['Verified'].unique()
# Out:
# array(['Verified'], dtype=object)

# %%
#Create DataFrame only containing required columns

clean_data = raw_data[['Reporter','ObsDate','DateEnt','Location','Longitude','Latitude','RecOwner']]

# %% [markdown]
# ### Clean Data Columns

# %%
raw_data['Reporter'].unique()
# Out:
# array(['Travis Mangione FWC', 'Edward F. Metzger III ',
#        'Michael Reupert NPS  Big Cypress National Preserve',
#        'matthew mccollister National Park Service, Big Cypress National Park',
#        'Jeffrey Fobb Miami-Dade Fire Rescue', 'Joshua Sands ',
#        'Matthew Bowser ', 'Christen Mason SFWMD', 'Sarah Norris ',
#        'Don Marchetto ',
#        'Amy Peters South Florida Water Management District',
#        'Ashley Provo ',
#        'Catherine Gelston Biscayne National Park - National Park Service',
#        'Vanessa McDonough Biscayne National Park', 'Amy Siewe None yet',
#        'Leah Miller Florida Bat Conservancy, Fakahatchee Strand Preserve SP & FL Panther Natl. Wildlife Refuge',
#        'Mark Danaher US Fish and Wildlife Service', 'Joey Cabrera ',
#        'David Shindle ', 'annette johnson nps',
#        'Jake Travers Florida Fish and Wildlife Conservation Commission',
#        'FWCC Exotic Species Database Florida Fish and Wildlife Conservation Commission',
#        'Madison Harman USGS', 'Kevin Reich ', 'Kevin Carlisle ',
#        'Cory Gillis ', 'Jeffrey Forsythe ', 'wayne owensby self',
#        'Christopher Gillette None',
#        'Steve Schulze Big Cypress National Preserve', 'Marsha Wheatley ',
#        'Jeremy Dixon USFWS',
#        'Trudy Ferraro John Pennekamp Coral Reef State Park', 'Fred Rice ',
#        'Matt Weiser ', 'Brian Waters NPS',
#        'Deborah Jansen Big Cypress National Preserve',
#        'Jake Edwards USDA Wildlife Services', 'Alexander Flores ',
#        'Anne Wood University of Oregon', 'Bob gore ', 'jarek anzelmo ',
#        'Ozzie Romero ', 'Elizabeth Scarlett USGS',
#        'Robert Hinson Big Cypress National Preserve', 'Mark Procter ',
#        'Jesssica Solis Mosaic', 'Josh Boyd ', 'Simon Williams ',
#        'Mathieu Basille University of Florida', 'Ross Firth Fisherman',
#        'Michael Kornofski ', 'Jake Cravens USAF', 'Meghan Massatt ',
#        'Juan Ospina ', 'Carlos Rodas ',
#        'Tony Pernas National Park Service',
#        'Jane Dozier Miami-Dade Park & Rec. Natural Areas Mgmt.',
#        'Bryan Earp ', 'Ian Bartoszek Conservancy of Southwest Florida',
#        'Jared Franklin Rookery Bay NERR', 'Brian Shaffer ',
#        'Ryan Brown South Florida Water Management District',
#        'Christina Stylianos South Florida Water Management District',
#        'Steven Bass Fakahatchee strand preserve state park',
#        'Erin Gallagher NPS', 'Keith Gifford ', 'Melody Ray-Culp USFWS',
#        'McKenzie Stewart USGS', 'Kurt Cox ', 'Norm Johnston ',
#        'Christopher Fisher ', 'Megan Digeon ', 'Andrew Pruchinski ',
#        'Michael Hoffman Biscayne National Park', 'Alex Laza ',
#        'Nicole Cortez ', 'Elena Suarez FWC', 'Reece Hammock ',
#        'Blake Russ ', 'Bill Booth Bill Booth Outdoors',
#        'Matthew Kozakoff ', 'Christopher Hipskind Private',
#        'Betsy Haley USDA APHIS Wildlife Services', 'Chris Hopkins ',
#        'Mary Helen Reuter Florida Panther NWR', 'jesus blanco ',
#        'Caleb Gallegos ', 'Brooke Dawson ', 'Julie Jacob ',
#        'Lori Oberhofer NPS / Everglades National Park',
#        'Molly DuVall Florida Fish and Wildlife Conservation Commission',
#        'Hunter Howell University of Miami', 'Bryan Falk NPS',
#        'Alex Roberts III Miami-Dade County DERM', 'Brian Smith USGS',
#        'Christopher Rizzie ', 'Michael Garrett Jr ', 'harrison cooper ',
#        'Donna Kalil ', 'Carrie Black FWC', 'Sandra Rommel Self',
#        'Ellen Donlan SFWMD', 'John Conners FWC', 'Steven Rebollar ',
#        'Thomas Aycock Swamp Apes', 'ronnie williams ',
#        'Rupert Lean Stretchmarine LLC', 'Bob Bramblet ',
#        'Venom One Miami Dade Fire Rescue', 'Brenda Jacobson ',
#        'Robert Ursich US Fish & Wildlife Service', 'Danaisy Serrano ',
#        'Tiffany Melvin Environmentally Endangered Lands Program',
#        'Jennifer Thelen NPS', 'Kelly Friman ',
#        'Charles Espenlaub Just a guy', 'Shauna Cotrell NPS',
#        'Kathleen Webster ', 'Aaron Swears ',
#        'Ross Scott Florida Fish and Wildlife Conservation Commission',
#        'Nile Charles N/A', 'Laura Elliott ',
#        'Luke Wassink Big Cypress NPS', 'joshua radford NPS',
#        'David Van Norman Volunteer Big Cypress National Preserve',
#        'Steve Daskam ', 'Ashley Hurt ', 'Ian Wogan True Tree Service',
#        'shawn keyte naturalist', 'Devi Hall ', 'jordan lopez ',
#        'Tim Johns Imperial Wilderness Condominium', 'Mike Elfenbein n/a',
#        'Lindsay McDonald FL Fish & Wildife Commission', 'Connie Bowman ',
#        'Christopher Kavanagh National Park Service', 'Ryan Maldonado ',
#        'Liz Huselid ', 'Andrew Eastwick U.S. Fish and Wildlife Service',
#        'Dino Barone ', 'Margie Pikarsky Bee Heaven Farm',
#        'Murray Barnhart ', 'Ian Easterling wildheart ecojourneys',
#        'Susie Nuttall FWC', 'Austin warne FWC / ZLaw Enforcement',
#        'Freddy Skelt SFNPCC', 'josh friers USDA WS',
#        'Joel Wilson Hollylake Homeowners Assoc.',
#        'Jesse Blanchard Florida International University',
#        'Victor Mousel ', 'Carol Mitchell Everglades National Park',
#        'William Mason ', 'Marvin Brown University of South Carolina',
#        'Will Andrus U.S. Army', 'Russell Hunt Lake & Wetland Management',
#        'Denton Woods N/A', 'Gregory Wheeler USDA/ARS',
#        'Brian Whitehead National Park Service', 'Daniel Otter ',
#        'Christine Thibodeau ', 'Donna Bishop ',
#        'Sean Perchalski National Park Service', 'John Sikoryak ',
#        'Brehan Furfey Florida Fish and Wildlife Conservation Commission',
#        'Hayley Crowell U.S. Geological Survey',
#        'Michelle Collier National Park Service',
#        'Sarah Steele Cabrera USFWS',
#        'James Duquesnel Monroe County Assistant Land Steward',
#        'Jeremy Parks ', 'Nicholas Ross ', 'Robert Cuevas NONE',
#        'Jake Edwards FWCC', 'Ian Markovich FWC',
#        'Sean Perchalski Whats Invasive', 'Patrick Fleming ',
#        'Eric Raits Shark Valley Tram Tours', 'Jose Diaz ',
#        'Devin Belliston ', 'Michiko Squires University of Florida',
#        'Lindsey Garner ', 'Don Witzel ',
#        'Larry Perez Everglades National Park', 'Glauco Puig-Santana ',
#        'Lelon Carroll U.S. Army Retired', 'Dylann Turffs none',
#        'Sara Williams University of Florida',
#        'Jessica Spencer US Army Corps of Engineers',
#        'Michelle Drake Sherwood ', 'Christopher Lee Nager ',
#        'Ruth Garner ', 'Angelina Gervasi N/a',
#        'Mike Owen DEP Florida Park Service', 'Bente Torvund DEP',
#        'Mike Taylor ', 'Julio Herrera ',
#        'Robin Bijlani University of Florida',
#        'US Army Corps of Engineers Ombil Database ',
#        'Bill McKee Broward County Parks', 'Bryan Falk USGS',
#        'Susan Ruch ', 'Danielle Majka ',
#        'LeRoy Rodgers South Florida Water Management District',
#        'Stephen Glines ', 'Antonio Dominguez FWC LEO',
#        'Joaquin Alonso NPS', 'Gary Frey ', 'LEONARDO SANCHEZ Aeromarine',
#        'Arthur Mabry ', 'Don McCumber Everglades Area Tours',
#        'Jimmy Jones Constrictor Catchers', 'Kendra Davis ',
#        'Michelle Curtis University of Florida',
#        'Adam Chasey National Audubon Society',
#        'Natural Areas Management NAM Miami-Dade County PROS Miami-Dade County',
#        'jericho hicks ENP', 'David` Snow ', 'Greg Curry FDEP / RBNERR',
#        'Pauline Haas Seminole Tribe of Florida',
#        'Laurie Humphrey Everglades National Park',
#        'Wellington Guzman University of Miami Hospitals', 'Joe Sheriff ',
#        'Jeffrey Gonzalez NPS', 'Richard Martinez ',
#        'ADRIANE TAMBASCO NONE', 'Gary Brumit ', 'Al Jacks ',
#        'Seth Farris University of Florida', 'Nancy Davis ',
#        'Bob Golenkow ', 'Josh Friers USDA WS',
#        'Charles LeBuff USFWS (ret.)',
#        'Steve Featherstone Oxford American Magazine',
#        'Todd Campbell University of Tampa', 'Gary Hyatt ',
#        'Jake Herndon ', 'Mark Massingham ',
#        'Brian Pavlina Institute For Regional Conservation',
#        'Alicie Warren Natural Areas Management, Miami-Dade County Parks, Recreation & Open Spaces Dept.',
#        'Lenny Batista ', 'Ruben Ramirez Florida Python Hunters',
#        'Ben Zahn Big Cypress National Preserve', 'Bryan Russ none',
#        'Michael Slager ', 'Eamonn Leonard Georgia DNR',
#        'Larry Bender retired', 'Joy Vinci University of Florida',
#        'Skip Snow Everglades National Park', 'Matt Litton None',
#        'Ashley Taylor FWC Volunteer', 'Kline Kendall ',
#        'Brian Jeffery University of Florida',
#        'Tad Bartareau Florida Fish and Wildlife Conservation Commission',
#        'Dominick Dulevich Institute for regional conservation',
#        'blake russ ', 'Allyson Gantt Everglades NP',
#        'Elsie Iudicello none', 'Yvette Cano Everglades National Park',
#        'Rob Leonard National park service', 'Katy Dimos none',
#        'Lazaro Quintino Miami-Dade DERM',
#        'Jean McCollom Florida Fish and Wildlife Conservation Commission',
#        'Chris Cannon 1979', 'Matthew Kemmer None',
#        'Joshua Holbrook Palm Beach Atlantic University',
#        'Daniel Culbert UF/IFAS Okeechobee Extension Service',
#        'Jeffrey Carter Rookery Bay NERR',
#        'Michael Renda The Nature Conservancy'], dtype=object)

# %%
#Create and clean first name column

clean_data['First_Name'] = clean_data['Reporter'].apply(lambda x: re.search('\w+ ',x).group(0).title().rstrip())
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Check output of above code

clean_data['First_Name'].unique()
# Out:
# array(['Travis', 'Edward', 'Michael', 'Matthew', 'Jeffrey', 'Joshua',
#        'Christen', 'Sarah', 'Don', 'Amy', 'Ashley', 'Catherine',
#        'Vanessa', 'Leah', 'Mark', 'Joey', 'David', 'Annette', 'Jake',
#        'Fwcc', 'Madison', 'Kevin', 'Cory', 'Wayne', 'Christopher',
#        'Steve', 'Marsha', 'Jeremy', 'Trudy', 'Fred', 'Matt', 'Brian',
#        'Deborah', 'Alexander', 'Anne', 'Bob', 'Jarek', 'Ozzie',
#        'Elizabeth', 'Robert', 'Jesssica', 'Josh', 'Simon', 'Mathieu',
#        'Ross', 'Meghan', 'Juan', 'Carlos', 'Tony', 'Jane', 'Bryan', 'Ian',
#        'Jared', 'Ryan', 'Christina', 'Steven', 'Erin', 'Keith', 'Melody',
#        'Mckenzie', 'Kurt', 'Norm', 'Megan', 'Andrew', 'Alex', 'Nicole',
#        'Elena', 'Reece', 'Blake', 'Bill', 'Betsy', 'Chris', 'Mary',
#        'Jesus', 'Caleb', 'Brooke', 'Julie', 'Lori', 'Molly', 'Hunter',
#        'Harrison', 'Donna', 'Carrie', 'Sandra', 'Ellen', 'John', 'Thomas',
#        'Ronnie', 'Rupert', 'Venom', 'Brenda', 'Danaisy', 'Tiffany',
#        'Jennifer', 'Kelly', 'Charles', 'Shauna', 'Kathleen', 'Aaron',
#        'Nile', 'Laura', 'Luke', 'Shawn', 'Devi', 'Jordan', 'Tim', 'Mike',
#        'Lindsay', 'Connie', 'Liz', 'Dino', 'Margie', 'Murray', 'Susie',
#        'Austin', 'Freddy', 'Joel', 'Jesse', 'Victor', 'Carol', 'William',
#        'Marvin', 'Will', 'Russell', 'Denton', 'Gregory', 'Daniel',
#        'Christine', 'Sean', 'Brehan', 'Hayley', 'Michelle', 'James',
#        'Nicholas', 'Patrick', 'Eric', 'Jose', 'Devin', 'Michiko',
#        'Lindsey', 'Larry', 'Glauco', 'Lelon', 'Dylann', 'Sara', 'Jessica',
#        'Ruth', 'Angelina', 'Bente', 'Julio', 'Robin', 'Us', 'Susan',
#        'Danielle', 'Leroy', 'Stephen', 'Antonio', 'Joaquin', 'Gary',
#        'Leonardo', 'Arthur', 'Jimmy', 'Kendra', 'Adam', 'Natural',
#        'Jericho', 'Snow', 'Greg', 'Pauline', 'Laurie', 'Wellington',
#        'Joe', 'Richard', 'Adriane', 'Al', 'Seth', 'Nancy', 'Todd',
#        'Alicie', 'Lenny', 'Ruben', 'Ben', 'Eamonn', 'Joy', 'Skip',
#        'Kline', 'Tad', 'Dominick', 'Allyson', 'Elsie', 'Yvette', 'Rob',
#        'Katy', 'Lazaro', 'Jean'], dtype=object)

# %%
#Clean leftover unclean data points

clean_data['First_Name'] = np.where(
    (clean_data['First_Name'].str.contains('Fwcc') 
     | clean_data['First_Name'].str.contains('Us') 
     | clean_data['First_Name'].str.contains('Snow') 
     | clean_data['First_Name'].str.contains('Snow') 
     | clean_data['First_Name'].str.contains('Skip') 
     | clean_data['First_Name'].str.contains('Natural') 
     | clean_data['First_Name'].str.contains('Venom')),
    'Government',
    clean_data['First_Name'],
)
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
#Final data check

clean_data['First_Name'].unique()
# Out:
# array(['Travis', 'Edward', 'Michael', 'Matthew', 'Jeffrey', 'Joshua',
#        'Christen', 'Sarah', 'Don', 'Amy', 'Ashley', 'Catherine',
#        'Vanessa', 'Leah', 'Mark', 'Joey', 'David', 'Annette', 'Jake',
#        'Government', 'Madison', 'Kevin', 'Cory', 'Wayne', 'Christopher',
#        'Steve', 'Marsha', 'Jeremy', 'Trudy', 'Fred', 'Matt', 'Brian',
#        'Deborah', 'Alexander', 'Anne', 'Bob', 'Jarek', 'Ozzie',
#        'Elizabeth', 'Robert', 'Jesssica', 'Josh', 'Simon', 'Mathieu',
#        'Ross', 'Meghan', 'Juan', 'Carlos', 'Tony', 'Jane', 'Bryan', 'Ian',
#        'Jared', 'Ryan', 'Christina', 'Steven', 'Erin', 'Keith', 'Melody',
#        'Mckenzie', 'Kurt', 'Norm', 'Megan', 'Andrew', 'Alex', 'Nicole',
#        'Elena', 'Reece', 'Blake', 'Bill', 'Betsy', 'Chris', 'Mary',
#        'Jesus', 'Caleb', 'Brooke', 'Julie', 'Lori', 'Molly', 'Hunter',
#        'Harrison', 'Donna', 'Carrie', 'Sandra', 'Ellen', 'John', 'Thomas',
#        'Ronnie', 'Rupert', 'Brenda', 'Danaisy', 'Tiffany', 'Jennifer',
#        'Kelly', 'Charles', 'Shauna', 'Kathleen', 'Aaron', 'Nile', 'Laura',
#        'Luke', 'Shawn', 'Devi', 'Jordan', 'Tim', 'Mike', 'Lindsay',
#        'Connie', 'Liz', 'Dino', 'Margie', 'Murray', 'Susie', 'Austin',
#        'Freddy', 'Joel', 'Jesse', 'Victor', 'Carol', 'William', 'Marvin',
#        'Will', 'Russell', 'Denton', 'Gregory', 'Daniel', 'Christine',
#        'Sean', 'Brehan', 'Hayley', 'Michelle', 'James', 'Nicholas',
#        'Patrick', 'Eric', 'Jose', 'Devin', 'Michiko', 'Lindsey', 'Larry',
#        'Glauco', 'Lelon', 'Dylann', 'Sara', 'Jessica', 'Ruth', 'Angelina',
#        'Bente', 'Julio', 'Robin', 'Susan', 'Danielle', 'Leroy', 'Stephen',
#        'Antonio', 'Joaquin', 'Gary', 'Leonardo', 'Arthur', 'Jimmy',
#        'Kendra', 'Adam', 'Jericho', 'Greg', 'Pauline', 'Laurie',
#        'Wellington', 'Joe', 'Richard', 'Adriane', 'Al', 'Seth', 'Nancy',
#        'Todd', 'Alicie', 'Lenny', 'Ruben', 'Ben', 'Eamonn', 'Joy',
#        'Kline', 'Tad', 'Dominick', 'Allyson', 'Elsie', 'Yvette', 'Rob',
#        'Katy', 'Lazaro', 'Jean'], dtype=object)

# %%
#Create and clean last name column

clean_data['Last_Name'] = clean_data['Reporter'].apply(lambda x: x.split(' ')[1].title().strip())
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Check output from code above

clean_data.head()
# Out:
#                                             Reporter      ObsDate  \
# 0                                Travis Mangione FWC  24 Nov 2019
# 1                             Edward F. Metzger III   20 Nov 2019
# 2  Michael Reupert NPS  Big Cypress National Pres...  07 Nov 2019
# 3  matthew mccollister National Park Service, Big...  06 Nov 2019
# 4  matthew mccollister National Park Service, Big...  05 Nov 2019
#
#        DateEnt                            Location  Longitude  Latitude  \
# 0  26 Nov 2019  Miami-Dade, Florida, United States  -80.74829  25.76191
# 1  22 Nov 2019     Broward, Florida, United States  -80.50567  26.29298
# 2  12 Nov 2019     Collier, Florida, United States  -81.10691  25.86434
# 3  07 Nov 2019     Collier, Florida, United States  -80.90326  25.83131
# 4  07 Nov 2019     Collier, Florida, United States  -81.18223  25.87197
#
#   RecOwner First_Name    Last_Name
# 0  Unknown     Travis     Mangione
# 1  Unknown     Edward           F.
# 2  Unknown    Michael      Reupert
# 3  Unknown    Matthew  Mccollister
# 4  Unknown    Matthew  Mccollister

# %%
clean_data['Last_Name'].unique()
# Out:
# array(['Mangione', 'F.', 'Reupert', 'Mccollister', 'Fobb', 'Sands',
#        'Bowser', 'Mason', 'Norris', 'Marchetto', 'Peters', 'Provo',
#        'Gelston', 'Mcdonough', 'Siewe', 'Miller', 'Danaher', 'Cabrera',
#        'Shindle', 'Johnson', 'Travers', 'Exotic', 'Harman', 'Reich',
#        'Carlisle', 'Gillis', 'Forsythe', 'Owensby', 'Gillette', 'Schulze',
#        'Wheatley', 'Dixon', 'Ferraro', 'Rice', 'Weiser', 'Waters',
#        'Jansen', 'Edwards', 'Flores', 'Wood', 'Gore', 'Anzelmo', 'Romero',
#        'Scarlett', 'Hinson', 'Procter', 'Solis', 'Boyd', 'Williams',
#        'Basille', 'Firth', 'Kornofski', 'Cravens', 'Massatt', 'Ospina',
#        'Rodas', 'Pernas', 'Dozier', 'Earp', 'Bartoszek', 'Franklin',
#        'Shaffer', 'Brown', 'Stylianos', 'Bass', 'Gallagher', 'Gifford',
#        'Ray-Culp', 'Stewart', 'Cox', 'Johnston', 'Fisher', 'Digeon',
#        'Pruchinski', 'Hoffman', 'Laza', 'Cortez', 'Suarez', 'Hammock',
#        'Russ', 'Booth', 'Kozakoff', 'Hipskind', 'Haley', 'Hopkins',
#        'Helen', 'Blanco', 'Gallegos', 'Dawson', 'Jacob', 'Oberhofer',
#        'Duvall', 'Howell', 'Falk', 'Roberts', 'Smith', 'Rizzie',
#        'Garrett', 'Cooper', 'Kalil', 'Black', 'Rommel', 'Donlan',
#        'Conners', 'Rebollar', 'Aycock', 'Lean', 'Bramblet', 'One',
#        'Jacobson', 'Ursich', 'Serrano', 'Melvin', 'Thelen', 'Friman',
#        'Espenlaub', 'Cotrell', 'Webster', 'Swears', 'Scott', 'Charles',
#        'Elliott', 'Wassink', 'Radford', 'Van', 'Daskam', 'Hurt', 'Wogan',
#        'Keyte', 'Hall', 'Lopez', 'Johns', 'Elfenbein', 'Mcdonald',
#        'Bowman', 'Kavanagh', 'Maldonado', 'Huselid', 'Eastwick', 'Barone',
#        'Pikarsky', 'Barnhart', 'Easterling', 'Nuttall', 'Warne', 'Skelt',
#        'Friers', 'Wilson', 'Blanchard', 'Mousel', 'Mitchell', 'Andrus',
#        'Hunt', 'Woods', 'Wheeler', 'Whitehead', 'Otter', 'Thibodeau',
#        'Bishop', 'Perchalski', 'Sikoryak', 'Furfey', 'Crowell', 'Collier',
#        'Steele', 'Duquesnel', 'Parks', 'Ross', 'Cuevas', 'Markovich',
#        'Fleming', 'Raits', 'Diaz', 'Belliston', 'Squires', 'Garner',
#        'Witzel', 'Perez', 'Puig-Santana', 'Carroll', 'Turffs', 'Spencer',
#        'Drake', 'Lee', 'Gervasi', 'Owen', 'Torvund', 'Taylor', 'Herrera',
#        'Bijlani', 'Army', 'Mckee', 'Ruch', 'Majka', 'Rodgers', 'Glines',
#        'Dominguez', 'Alonso', 'Frey', 'Sanchez', 'Mabry', 'Mccumber',
#        'Jones', 'Davis', 'Curtis', 'Chasey', 'Areas', 'Hicks', 'Snow',
#        'Curry', 'Haas', 'Humphrey', 'Guzman', 'Sheriff', 'Gonzalez',
#        'Martinez', 'Tambasco', 'Brumit', 'Jacks', 'Farris', 'Golenkow',
#        'Lebuff', 'Featherstone', 'Campbell', 'Hyatt', 'Herndon',
#        'Massingham', 'Pavlina', 'Warren', 'Batista', 'Ramirez', 'Zahn',
#        'Slager', 'Leonard', 'Bender', 'Vinci', 'Litton', 'Kendall',
#        'Jeffery', 'Bartareau', 'Dulevich', 'Gantt', 'Iudicello', 'Cano',
#        'Dimos', 'Quintino', 'Mccollom', 'Cannon', 'Kemmer', 'Holbrook',
#        'Culbert', 'Carter', 'Renda'], dtype=object)

# %%
#Clean leftover unclean data points

clean_data['Last_Name'] = np.where(
    clean_data['First_Name'].str.contains('Government'),
    'Agency',
    clean_data['Last_Name'],
)

clean_data['Last_Name'] = np.where(
    clean_data['Last_Name'].str.contains('F.'),
    'Metzger',
    clean_data['Last_Name'],
)
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
#Create new column for the county where the observations occured

clean_data['County'] = clean_data['Location'].apply(lambda x: re.sub(',.*','', x))
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# clean_data[clean_data['First_Name'] == 'Wayne']

# %%
#Clean location column to only include observations that occured in Florida

clean_data = clean_data[clean_data['Location'].str.contains('Florida')]

# %%
#Check output of above code

clean_data['Location'].unique()
# Out:
# array(['Miami-Dade, Florida, United States',
#        'Broward, Florida, United States',
#        'Collier, Florida, United States',
#        'Monroe, Florida, United States',
#        'Palm Beach, Florida, United States',
#        'Polk, Florida, United States', 'Orange, Florida, United States',
#        'Manatee, Florida, United States',
#        'Sarasota, Florida, United States',
#        'Volusia, Florida, United States', 'Lee, Florida, United States',
#        'Glades, Florida, United States',
#        'Okeechobee, Florida, United States',
#        'Hendry, Florida, United States',
#        'Alachua, Florida, United States',
#        'Hernando, Florida, United States',
#        'Marion, Florida, United States', 'Pasco, Florida, United States',
#        'Pinellas, Florida, United States',
#        'Highlands, Florida, United States',
#        'Osceola, Florida, United States',
#        'Charlotte, Florida, United States',
#        'St. Lucie, Florida, United States',
#        'Clay, Florida, United States', 'Martin, Florida, United States',
#        'Hillsborough, Florida, United States',
#        'Brevard, Florida, United States',
#        'Washington, Florida, United States',
#        'Flagler, Florida, United States',
#        'Indian River, Florida, United States',
#        'Duval, Florida, United States',
#        'Seminole, Florida, United States'], dtype=object)

# %%
#Final Data Check

clean_data.head()
# Out:
#                                             Reporter      ObsDate  \
# 0                                Travis Mangione FWC  24 Nov 2019
# 1                             Edward F. Metzger III   20 Nov 2019
# 2  Michael Reupert NPS  Big Cypress National Pres...  07 Nov 2019
# 3  matthew mccollister National Park Service, Big...  06 Nov 2019
# 4  matthew mccollister National Park Service, Big...  05 Nov 2019
#
#        DateEnt                            Location  Longitude  Latitude  \
# 0  26 Nov 2019  Miami-Dade, Florida, United States  -80.74829  25.76191
# 1  22 Nov 2019     Broward, Florida, United States  -80.50567  26.29298
# 2  12 Nov 2019     Collier, Florida, United States  -81.10691  25.86434
# 3  07 Nov 2019     Collier, Florida, United States  -80.90326  25.83131
# 4  07 Nov 2019     Collier, Florida, United States  -81.18223  25.87197
#
#   RecOwner First_Name    Last_Name      County
# 0  Unknown     Travis     Mangione  Miami-Dade
# 1  Unknown     Edward      Metzger     Broward
# 2  Unknown    Michael      Reupert     Collier
# 3  Unknown    Matthew  Mccollister     Collier
# 4  Unknown    Matthew  Mccollister     Collier

# %% [markdown]
# ### Send DataFrame to CSV

# %%
clean_data.to_csv('Python_Gov_Observations_Clean.csv', index = False)
